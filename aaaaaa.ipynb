# %%
import requests
from bs4 import BeautifulSoup
from time import sleep 
from random import random


import json
import urllib.request
base_url = 'http://www.portaldatransparencia.gov.br/'

def read_table(table):
    rows = table.findAll("tr")
    header = rows[0]
    #print ('header')
    cols = header.findAll('th')
    #print ('# of cols' + str(len(cols)))

    my_json = []
    
    #for col in cols:
        #print (col.getText().strip())

    for row in range(1,len(rows)):
        my_dict = {}
        
        a = 'row ' + str(row)
        cols = rows[row].findAll("td", {"class":"firstChild"})
        cols_valor = rows[row].findAll("td", {"class":"colunaValor"})
        for col in cols:
            for col2 in cols_valor:
                b = col2.getText().strip()
            c = col.getText().strip()
        
        
        my_dict['Linha'] = a
        my_dict['Mes'] = b
        my_dict['Valor'] = c
        my_json.append(my_dict)
    
    return my_json
   
    
    
    
def read_person(person_url):
    #print (person_url)
    person = urllib.request.urlopen(person_url)
    person_soup = BeautifulSoup(person, "lxml")

    tables = person_soup.findAll("table")
    g = read_table(tables[1])
    #h = json.dumps(g, indent=4, sort_keys=True)
    return g
    
    
read_person('http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=6296326&cpfcnpjnis=00016167611395')

# %%
import urllib.request

def read_city_page(city_page_url):
    #print (city_page_url)
    city_page = urllib.request.urlopen(city_page_url)
    city_page_soup = BeautifulSoup(city_page, "lxml")

    tables = city_page_soup.findAll("table")
    rows = tables[1].findAll("tr")
    header = rows[0]
    #print ('header')
    lista = []
    cols = header.findAll('th')
    for col in cols:
        linhas = {}
        #print (col.getText())

    for row in range(1,len(rows)):
        print ('row ' + str(row))
        cols = rows[row].findAll('td')
        cols_nis = rows[row].findAll("td", {"class":"firstChild"})
        for col in cols:
            #print (col)
            for col2 in cols_nis:
                c = col2.getText().strip()
            b =  col.getText().strip()
            linhas['nis'] = c
            a = col.find('a')
            
            #print (teste)
            if a is not None:
                person_url = base_url + a.get('href')
                #print (person_url)
                js = read_person(person_url)
                linhas ['valor_detalhes'] = []
                linhas ['valor_detalhes'].append(js)
                linhas['nome'] = b
                
           
           
            linhas['valor'] = b
            sleep(1+random())
        
        
        #h = json.dumps(linhas, indent=4, sort_keys=True)
        lista.append(linhas)
    return lista
            

                
read_city_page('http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoFavorecido.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&Pagina=1')

# %%
def read_city(city_url):
    print (city_url)
    b = []
    c = []
    d = {}
    city_page = urllib.request.urlopen(city_url)
    city_page_soup = BeautifulSoup(city_page, "lxml")
    city_pagination = city_page_soup.find(id='paginacao').p.getText()
    print(city_pagination)
    city_pages = str.split(city_pagination, '/')[1]
    print (city_pages)
    for city_page in range(1,int(city_pages)+1):
        city_page_url = city_url + '&Pagina=' + str(city_page)
        print ('\nPAGINA ' + str(city_page))
        a = read_city_page(city_page_url)
        d['pagina '+ str(city_page)] = a
        sleep(1+random())
       
        d["total_de_paginas"] = city_page
        with open('teste_acrelandia.json', 'w') as arquivo:
            json.dump(d, arquivo, indent=4, sort_keys=True)

        

read_city('http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoFavorecido.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643')
# Out:
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoFavorecido.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643
# Página 1/139
# 139
#
# PAGINA 1
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 2
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 3
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 4
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 5
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 6
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 7
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 8
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 9
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 10
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 11
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 12
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 13
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 14
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 15
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 16
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 17
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 18
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 19
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 20
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 21
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 22
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 23
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 24
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 25
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 26
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 27
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 28
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 29
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 30
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 31
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 32
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 33
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 34
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 35
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 36
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 37
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 38
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 39
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 40
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 41
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 42
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 43
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 44
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 45
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 46
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 47
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 48
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 49
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 50
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 51
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 52
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 53
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 54
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 55
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 56
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 57
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 58
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 59
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 60
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 61
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 62
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
#
# PAGINA 63
# row 1
# row 2
# row 3
# row 4
# row 5
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# C:\Users\Gargano\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1253             try:
# -> 1254                 h.request(req.get_method(), req.selector, req.data, headers)
#    1255             except OSError as err: # timeout error
#
# C:\Users\Gargano\Anaconda3\lib\http\client.py in request(self, method, url, body, headers)
#    1105         """Send a complete request to the server."""
# -> 1106         self._send_request(method, url, body, headers)
#    1107
#
# C:\Users\Gargano\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers)
#    1150             body = _encode(body, 'body')
# -> 1151         self.endheaders(body)
#    1152
#
# C:\Users\Gargano\Anaconda3\lib\http\client.py in endheaders(self, message_body)
#    1101             raise CannotSendHeader()
# -> 1102         self._send_output(message_body)
#    1103
#
# C:\Users\Gargano\Anaconda3\lib\http\client.py in _send_output(self, message_body)
#     933
# --> 934         self.send(msg)
#     935         if message_body is not None:
#
# C:\Users\Gargano\Anaconda3\lib\http\client.py in send(self, data)
#     876             if self.auto_open:
# --> 877                 self.connect()
#     878             else:
#
# C:\Users\Gargano\Anaconda3\lib\http\client.py in connect(self)
#     848         self.sock = self._create_connection(
# --> 849             (self.host,self.port), self.timeout, self.source_address)
#     850         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# C:\Users\Gargano\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     710     if err is not None:
# --> 711         raise err
#     712     else:
#
# C:\Users\Gargano\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     701                 sock.bind(source_address)
# --> 702             sock.connect(sa)
#     703             return sock
#
# TimeoutError: [WinError 10060] Uma tentativa de conexão falhou porque o componente conectado não respondeu
# corretamente após um período de tempo ou a conexão estabelecida falhou
# porque o host conectado não respondeu
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-13-4175eb1cfac3> in <module>()
#      25
#      26
# ---> 27 read_city('http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoFavorecido.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643')
#
# <ipython-input-13-4175eb1cfac3> in read_city(city_url)
#      15         city_page_url = city_url + '&Pagina=' + str(city_page)
#      16         print ('\nPAGINA ' + str(city_page))
# ---> 17         a = read_city_page(city_page_url)
#      18         d['pagina '+ str(city_page)] = a
#      19         sleep(1+random())
#
# <ipython-input-11-efe69abd2237> in read_city_page(city_page_url)
#      32                 person_url = base_url + a.get('href')
#      33                 #print (person_url)
# ---> 34                 js = read_person(person_url)
#      35                 linhas ['valor_detalhes'] = []
#      36                 linhas ['valor_detalhes'].append(js)
#
# <ipython-input-7-3b54b8d204cc> in read_person(person_url)
#      42 def read_person(person_url):
#      43     #print (person_url)
# ---> 44     person = urllib.request.urlopen(person_url)
#      45     person_soup = BeautifulSoup(person, "lxml")
#      46
#
# C:\Users\Gargano\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# C:\Users\Gargano\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     464             req = meth(req)
#     465
# --> 466         response = self._open(req, data)
#     467
#     468         # post-process response
#
# C:\Users\Gargano\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     482         protocol = req.type
#     483         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 484                                   '_open', req)
#     485         if result:
#     486             return result
#
# C:\Users\Gargano\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     442         for handler in handlers:
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#     446                 return result
#
# C:\Users\Gargano\Anaconda3\lib\urllib\request.py in http_open(self, req)
#    1280
#    1281     def http_open(self, req):
# -> 1282         return self.do_open(http.client.HTTPConnection, req)
#    1283
#    1284     http_request = AbstractHTTPHandler.do_request_
#
# C:\Users\Gargano\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1254                 h.request(req.get_method(), req.selector, req.data, headers)
#    1255             except OSError as err: # timeout error
# -> 1256                 raise URLError(err)
#    1257             r = h.getresponse()
#    1258         except:
#
# URLError: <urlopen error [WinError 10060] Uma tentativa de conexão falhou porque o componente conectado não respondeu
# corretamente após um período de tempo ou a conexão estabelecida falhou
# porque o host conectado não respondeu>
