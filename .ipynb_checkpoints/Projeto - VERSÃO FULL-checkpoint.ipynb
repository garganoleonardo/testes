# %%
import requests
from bs4 import BeautifulSoup

import json
import urllib.request
base_url = 'http://www.portaldatransparencia.gov.br/'

def read_table(table):
    rows = table.findAll("tr")
    header = rows[0]
    print ('header')
    cols = header.findAll('th')
    print ('# of cols' + str(len(cols)))

    my_json = []
    
    for col in cols:
        print (col.getText().strip())

    for row in range(1,len(rows)):
        my_dict = {}
        
        a = 'row ' + str(row)
        cols = rows[row].findAll("td", {"class":"firstChild"})
        cols_valor = rows[row].findAll("td", {"class":"colunaValor"})
        for col in cols:
            for col2 in cols_valor:
                b = col2.getText().strip()
            c = col.getText().strip()
        
        
        my_dict['Linha'] = a
        my_dict['Mes'] = c
        my_dict['Valor'] = b 
        my_json.append(my_dict)
    
    return my_json
   
    
    
    
def read_person(person_url):
    print (person_url)
    person = urllib.request.urlopen(person_url)
    person_soup = BeautifulSoup(person, "lxml")

    tables = person_soup.findAll("table")
    g = read_table(tables[1])
    h = json.dumps(g, indent=4, sort_keys=True)
    return h
    
    
    
read_person('http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=6296326&cpfcnpjnis=00016167611395')
# Out:
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=6296326&cpfcnpjnis=00016167611395
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# '[\n    {\n        "Linha": "row 1",\n        "Mes": "Outubro/2016",\n        "Valor": "209,00"\n    },\n    {\n        "Linha": "row 2",\n        "Mes": "Setembro/2016",\n        "Valor": "209,00"\n    },\n    {\n        "Linha": "row 3",\n        "Mes": "Agosto/2016",\n        "Valor": "209,00"\n    },\n    {\n        "Linha": "row 4",\n        "Mes": "Julho/2016",\n        "Valor": "209,00"\n    },\n    {\n        "Linha": "row 5",\n        "Mes": "Junho/2016",\n        "Valor": "189,00"\n    },\n    {\n        "Linha": "row 6",\n        "Mes": "Maio/2016",\n        "Valor": "189,00"\n    },\n    {\n        "Linha": "row 7",\n        "Mes": "Abril/2016",\n        "Valor": "189,00"\n    },\n    {\n        "Linha": "row 8",\n        "Mes": "Mar\\u00e7o/2016",\n        "Valor": "189,00"\n    },\n    {\n        "Linha": "row 9",\n        "Mes": "Fevereiro/2016",\n        "Valor": "189,00"\n    },\n    {\n        "Linha": "row 10",\n        "Mes": "Janeiro/2016",\n        "Valor": "189,00"\n    }\n]'

# %%
import urllib.request

def read_city_page(city_page_url):
    print (city_page_url)
    city_page = urllib.request.urlopen(city_page_url)
    city_page_soup = BeautifulSoup(city_page, "lxml")

    tables = city_page_soup.findAll("table")
    rows = tables[1].findAll("tr")
    header = rows[0]
    print ('header')
    lista = []
    js2 = ""
    cols = header.findAll('th')
    for col in cols:
        linhas = {}
        print (col.getText())

    for row in range(1,len(rows)):
        print ('row ' + str(row))
        cols = rows[row].findAll('td')
        cols_nis = rows[row].findAll("td", {"class":"firstChild"})
        for col in cols:
            #print (col)
            for col2 in cols_nis:
                c = col2.getText().strip()
            b =  col.getText().strip()
            linhas['nis'] = c
            a = col.find('a')
            
            #print (teste)
            if a is not None:
                person_url = base_url + a.get('href')
                print (person_url)
                js = read_person(person_url)
                linhas ['valor_detalhes'] = []
                linhas ['valor_detalhes'].append(js)
                linhas['nome'] = b
           
           
            linhas['valor'] = b
        
        
        print (json.dumps(linhas, indent=4, sort_keys=True))
            

                
read_city_page('http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoFavorecido.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&Pagina=1')
# Out:
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoFavorecido.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&Pagina=1
# header
# CNPJ/CPF/NIS/Outros
# Favorecido [Nome Fantasia]
# Total no Ano (R$)
# row 1
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=6296326&cpfcnpjnis=00016167611395
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=6296326&cpfcnpjnis=00016167611395
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "161.67611.39-5",
#     "nome": "ABIGAIL DAGMAR MACHADO",
#     "valor": "1.970,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"209,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"209,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"209,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"209,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"189,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"189,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"189,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"189,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"189,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"189,00\"\n    }\n]"
#     ]
# }
# row 2
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=3466723&cpfcnpjnis=00020225359582
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=3466723&cpfcnpjnis=00020225359582
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "202.25359.58-2",
#     "nome": "ADACIA CARDOSO FIRME",
#     "valor": "2.146,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"229,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"229,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"229,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"229,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"205,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"205,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"205,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"205,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"205,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"205,00\"\n    }\n]"
#     ]
# }
# row 3
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=9774049&cpfcnpjnis=00010679398837
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=9774049&cpfcnpjnis=00010679398837
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "106.79398.83-7",
#     "nome": "ADAIR FERREIRA",
#     "valor": "1.270,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"85,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"85,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"85,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"85,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"155,00\"\n    }\n]"
#     ]
# }
# row 4
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=11796961&cpfcnpjnis=00020796469754
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=11796961&cpfcnpjnis=00020796469754
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "207.96469.75-4",
#     "nome": "ADALCICLEIA BARROS DE ARAUJO",
#     "valor": "942,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"157,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"157,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"157,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"157,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"157,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"157,00\"\n    }\n]"
#     ]
# }
# row 5
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=11257149&cpfcnpjnis=00021221461240
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=11257149&cpfcnpjnis=00021221461240
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "212.21461.24-0",
#     "nome": "ADALCILEIA BARROS DE ARAUJO",
#     "valor": "1.804,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"241,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"241,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"241,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"241,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"140,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"140,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"140,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"140,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"140,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"140,00\"\n    }\n]"
#     ]
# }
# row 6
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=3550714&cpfcnpjnis=00016120063855
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=3550714&cpfcnpjnis=00016120063855
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "161.20063.85-5",
#     "nome": "ADALGIZA NOGUEIRA DOS SANTOS",
#     "valor": "1.996,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"257,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"257,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"257,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"257,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"233,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"147,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"147,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"147,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"147,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"147,00\"\n    }\n]"
#     ]
# }
# row 7
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=9054730&cpfcnpjnis=00023721371727
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=9054730&cpfcnpjnis=00023721371727
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "237.21371.72-7",
#     "nome": "ADAO ANTONIO DA SILVA",
#     "valor": "1.272,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"171,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"171,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"155,00\"\n    }\n]"
#     ]
# }
# row 8
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=14916658&cpfcnpjnis=00021208225415
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=14916658&cpfcnpjnis=00021208225415
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "212.08225.41-5",
#     "nome": "ADEIDE RODRIGUES DAMASCENO",
#     "valor": "2.298,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"342,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"342,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"342,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"342,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"310,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"310,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"310,00\"\n    }\n]"
#     ]
# }
# row 9
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=7880435&cpfcnpjnis=00023684077492
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=7880435&cpfcnpjnis=00023684077492
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-eeed0f2dd4b9> in <module>()
#      46
#      47
# ---> 48 read_city_page('http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoFavorecido.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&Pagina=1')
#
# <ipython-input-20-eeed0f2dd4b9> in read_city_page(city_page_url)
#      33                 person_url = base_url + a.get('href')
#      34                 print (person_url)
# ---> 35                 js = read_person(person_url)
#      36                 linhas ['valor_detalhes'] = []
#      37                 linhas ['valor_detalhes'].append(js)
#
# <ipython-input-15-b8735ce6c0d3> in read_person(person_url)
#      42 def read_person(person_url):
#      43     print (person_url)
# ---> 44     person = urllib.request.urlopen(person_url)
#      45     person_soup = BeautifulSoup(person, "lxml")
#      46
#
# C:\Users\Léo\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# C:\Users\Léo\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     464             req = meth(req)
#     465
# --> 466         response = self._open(req, data)
#     467
#     468         # post-process response
#
# C:\Users\Léo\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     482         protocol = req.type
#     483         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 484                                   '_open', req)
#     485         if result:
#     486             return result
#
# C:\Users\Léo\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     442         for handler in handlers:
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#     446                 return result
#
# C:\Users\Léo\Anaconda3\lib\urllib\request.py in http_open(self, req)
#    1280
#    1281     def http_open(self, req):
# -> 1282         return self.do_open(http.client.HTTPConnection, req)
#    1283
#    1284     http_request = AbstractHTTPHandler.do_request_
#
# C:\Users\Léo\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1255             except OSError as err: # timeout error
#    1256                 raise URLError(err)
# -> 1257             r = h.getresponse()
#    1258         except:
#    1259             h.close()
#
# C:\Users\Léo\Anaconda3\lib\http\client.py in getresponse(self)
#    1195         try:
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#    1199                 self.close()
#
# C:\Users\Léo\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# C:\Users\Léo\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# C:\Users\Léo\Anaconda3\lib\socket.py in readinto(self, b)
#     573         while True:
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#     577                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
def read_city(city_url):
    print (city_url)
    city_page = urllib.request.urlopen(city_url)
    city_page_soup = BeautifulSoup(city_page, "lxml")
    city_pagination = city_page_soup.find(id='paginacao').p.getText()
    print(city_pagination)
    city_pages = str.split(city_pagination, '/')[1]
    print (city_pages)
    for city_page in range(1,int(city_pages)+1):
        city_page_url = city_url + '&Pagina=' + str(city_page)
        print ('\nPAGINA' + str(city_page))
        read_city_page(city_page_url)
        

read_city('http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoFavorecido.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643')
# Out:
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoFavorecido.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643
# Página 1/139
# 139
#
# PAGINA1
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoFavorecido.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&Pagina=1
# header
# CNPJ/CPF/NIS/Outros
# Favorecido [Nome Fantasia]
# Total no Ano (R$)
# row 1
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=6296326&cpfcnpjnis=00016167611395
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=6296326&cpfcnpjnis=00016167611395
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "161.67611.39-5",
#     "nome": "ABIGAIL DAGMAR MACHADO",
#     "valor": "1.970,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"209,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"209,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"209,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"209,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"189,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"189,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"189,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"189,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"189,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"189,00\"\n    }\n]"
#     ]
# }
# row 2
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=3466723&cpfcnpjnis=00020225359582
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=3466723&cpfcnpjnis=00020225359582
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "202.25359.58-2",
#     "nome": "ADACIA CARDOSO FIRME",
#     "valor": "2.146,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"229,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"229,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"229,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"229,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"205,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"205,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"205,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"205,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"205,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"205,00\"\n    }\n]"
#     ]
# }
# row 3
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=9774049&cpfcnpjnis=00010679398837
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=9774049&cpfcnpjnis=00010679398837
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "106.79398.83-7",
#     "nome": "ADAIR FERREIRA",
#     "valor": "1.270,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"85,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"85,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"85,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"85,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"155,00\"\n    }\n]"
#     ]
# }
# row 4
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=11796961&cpfcnpjnis=00020796469754
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=11796961&cpfcnpjnis=00020796469754
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "207.96469.75-4",
#     "nome": "ADALCICLEIA BARROS DE ARAUJO",
#     "valor": "942,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"157,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"157,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"157,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"157,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"157,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"157,00\"\n    }\n]"
#     ]
# }
# row 5
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=11257149&cpfcnpjnis=00021221461240
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=11257149&cpfcnpjnis=00021221461240
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "212.21461.24-0",
#     "nome": "ADALCILEIA BARROS DE ARAUJO",
#     "valor": "1.804,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"241,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"241,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"241,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"241,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"140,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"140,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"140,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"140,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"140,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"140,00\"\n    }\n]"
#     ]
# }
# row 6
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=3550714&cpfcnpjnis=00016120063855
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=3550714&cpfcnpjnis=00016120063855
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "161.20063.85-5",
#     "nome": "ADALGIZA NOGUEIRA DOS SANTOS",
#     "valor": "1.996,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"257,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"257,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"257,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"257,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"233,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"147,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"147,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"147,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"147,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"147,00\"\n    }\n]"
#     ]
# }
# row 7
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=9054730&cpfcnpjnis=00023721371727
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=9054730&cpfcnpjnis=00023721371727
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "237.21371.72-7",
#     "nome": "ADAO ANTONIO DA SILVA",
#     "valor": "1.272,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"171,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"171,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"155,00\"\n    }\n]"
#     ]
# }
# row 8
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=14916658&cpfcnpjnis=00021208225415
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=14916658&cpfcnpjnis=00021208225415
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "212.08225.41-5",
#     "nome": "ADEIDE RODRIGUES DAMASCENO",
#     "valor": "2.298,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"342,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"342,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"342,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"342,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"310,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"310,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"310,00\"\n    }\n]"
#     ]
# }
# row 9
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=7880435&cpfcnpjnis=00023684077492
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=7880435&cpfcnpjnis=00023684077492
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "236.84077.49-2",
#     "nome": "ADELCILENE SOARES DA COSTA",
#     "valor": "1.272,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"171,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"171,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"155,00\"\n    }\n]"
#     ]
# }
# row 10
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=11824565&cpfcnpjnis=00021273189347
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=11824565&cpfcnpjnis=00021273189347
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "212.73189.34-7",
#     "nome": "ADELIA DA COSTA PASSOS",
#     "valor": "2.858,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"305,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"305,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"305,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"305,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"273,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"273,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"273,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"273,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"273,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"273,00\"\n    }\n]"
#     ]
# }
# row 11
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=2777808&cpfcnpjnis=00019033685003
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=2777808&cpfcnpjnis=00019033685003
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "190.33685.00-3",
#     "nome": "ADELIANE BRITO SANTIAGO",
#     "valor": "899,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"124,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"124,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"112,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"112,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"112,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"105,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"105,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"105,00\"\n    }\n]"
#     ]
# }
# row 12
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=4196345&cpfcnpjnis=00016036929952
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=4196345&cpfcnpjnis=00016036929952
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "160.36929.95-2",
#     "nome": "ADELINA XUITES JACOB",
#     "valor": "5.634,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"597,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"597,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"597,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"597,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"541,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"541,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"541,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"541,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"541,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"541,00\"\n    }\n]"
#     ]
# }
# row 13
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=12286525&cpfcnpjnis=00020500011774
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=12286525&cpfcnpjnis=00020500011774
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "205.00011.77-4",
#     "nome": "ADENILDA TAVARES DA SILVA",
#     "valor": "2.513,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"317,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"318,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"318,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"318,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"286,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"286,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"286,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"128,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"128,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"128,00\"\n    }\n]"
#     ]
# }
# row 14
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=15511674&cpfcnpjnis=00020326549867
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=15511674&cpfcnpjnis=00020326549867
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "203.26549.86-7",
#     "nome": "ADENILZA MACHADO PINHEIRO",
#     "valor": "296,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"148,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"148,00\"\n    }\n]"
#     ]
# }
# row 15
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=4007033&cpfcnpjnis=00020666423150
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=4007033&cpfcnpjnis=00020666423150
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "206.66423.15-0",
#     "nome": "ADEUDILENE MARIA PAULA DE OLIVEIRA",
#     "valor": "1.796,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"194,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"194,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"194,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"194,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"170,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"170,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"170,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"170,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"170,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"170,00\"\n    }\n]"
#     ]
# }
#
# PAGINA2
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoFavorecido.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&Pagina=2
# header
# CNPJ/CPF/NIS/Outros
# Favorecido [Nome Fantasia]
# Total no Ano (R$)
# row 1
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=7724701&cpfcnpjnis=00013630107310
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=7724701&cpfcnpjnis=00013630107310
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "136.30107.31-0",
#     "nome": "ADEVANIL DA SILVA",
#     "valor": "2.658,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"285,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"285,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"285,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"285,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"253,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"253,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"253,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"253,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"253,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"253,00\"\n    }\n]"
#     ]
# }
# row 2
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=7354746&cpfcnpjnis=00020046062070
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=7354746&cpfcnpjnis=00020046062070
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "200.46062.07-0",
#     "nome": "ADICLEIA OTTENIO DE SOUZA",
#     "valor": "1.168,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"124,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"124,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"124,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"124,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"112,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"112,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"112,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"112,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"112,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"112,00\"\n    }\n]"
#     ]
# }
# row 3
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=6396104&cpfcnpjnis=00023684032049
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=6396104&cpfcnpjnis=00023684032049
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-83bbc05e708b> in <module>()
#      13
#      14
# ---> 15 read_city('http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoFavorecido.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643')
#
# <ipython-input-16-83bbc05e708b> in read_city(city_url)
#      10         city_page_url = city_url + '&Pagina=' + str(city_page)
#      11         print ('\nPAGINA' + str(city_page))
# ---> 12         read_city_page(city_page_url)
#      13
#      14
#
# <ipython-input-2-eeed0f2dd4b9> in read_city_page(city_page_url)
#      33                 person_url = base_url + a.get('href')
#      34                 print (person_url)
# ---> 35                 js = read_person(person_url)
#      36                 linhas ['valor_detalhes'] = []
#      37                 linhas ['valor_detalhes'].append(js)
#
# <ipython-input-15-b8735ce6c0d3> in read_person(person_url)
#      42 def read_person(person_url):
#      43     print (person_url)
# ---> 44     person = urllib.request.urlopen(person_url)
#      45     person_soup = BeautifulSoup(person, "lxml")
#      46
#
# C:\Users\Léo\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# C:\Users\Léo\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     464             req = meth(req)
#     465
# --> 466         response = self._open(req, data)
#     467
#     468         # post-process response
#
# C:\Users\Léo\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     482         protocol = req.type
#     483         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 484                                   '_open', req)
#     485         if result:
#     486             return result
#
# C:\Users\Léo\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     442         for handler in handlers:
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#     446                 return result
#
# C:\Users\Léo\Anaconda3\lib\urllib\request.py in http_open(self, req)
#    1280
#    1281     def http_open(self, req):
# -> 1282         return self.do_open(http.client.HTTPConnection, req)
#    1283
#    1284     http_request = AbstractHTTPHandler.do_request_
#
# C:\Users\Léo\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1255             except OSError as err: # timeout error
#    1256                 raise URLError(err)
# -> 1257             r = h.getresponse()
#    1258         except:
#    1259             h.close()
#
# C:\Users\Léo\Anaconda3\lib\http\client.py in getresponse(self)
#    1195         try:
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#    1199                 self.close()
#
# C:\Users\Léo\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# C:\Users\Léo\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# C:\Users\Léo\Anaconda3\lib\socket.py in readinto(self, b)
#     573         while True:
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#     577                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
def read_state_page(state_page_url):
    #print (state_page_url)
    state_page = urllib.request.urlopen(state_page_url)
    state_page_soup = BeautifulSoup(state_page, "lxml")

    for td in state_page_soup.findAll("td", {"class":"firstChild"}):
        if td.a is not None:
            print ("ESTOU AQUI "+td.a.getText())
            city_url = base_url + td.a.get('href')
            print ('SOU O  city_url\n'+ city_url)
            read_city(city_url)
            


def read_state(state_url):
    print ("SOU O state_url\n" +state_url)
    state_page = urllib.request.urlopen(state_url)
    state_page_soup = BeautifulSoup(state_page, "lxml")
    state_pagination = state_page_soup.find(id='paginacao').p.getText()
    print("SOU O state_pagination\n"+state_pagination)
    state_pages = str.split(state_pagination, '/')[1]
    print ("SOU O state_pages\n"+state_pages)
    state_pages = 1
    for state_page in range(1,int(state_pages)+1):
        state_page_url = state_url + '&Pagina=' + str(state_page)
        print ("SOU O state_page_url\n"+ state_page_url)
        read_state_page(state_page_url)

# %%
main_url = 'http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoUF.asp?codigoAcao=8442&codigoFuncao=08&NomeAcao=Transfer%EAncia+de+Renda+Diretamente+%E0s+Fam%EDlias+em+Condi%E7%E3o+de+Pobreza+e+Extrema+Pobreza+%28Lei+n%BA+10%2E836%2C+de+2004%29&Exercicio=2016'
def read_main_page(main_url):
    #print (main_page_url+" ESTOU AQUI")
    main_page = urllib.request.urlopen(main_url)
    main_page_soup = BeautifulSoup(main_page, "lxml")
    for td in main_page_soup.findAll("td", {"class":"firstChild"}):
        if td.a is not None:
            print (td.a.getText())
            state_url = base_url + td.a.get('href')
            #print(state_url)
            read_state(state_url)

def read_main(main_url):
    main_page = urllib.request.urlopen(main_url)
    soup = BeautifulSoup(main_page, "lxml")
    pagination = soup.find(id='paginacao').p.getText()
    print(pagination)  
    pages = str.split(pagination, '/')[1]
    print (pages)
    for main_page in range(1,int(pages)+1):
        main_page_url = main_url + '&Pagina=' + str(main_page)
        print('eu sou o main_page_url \n'+main_page_url)
        read_main_page(main_page_url)
        

read_main(main_url)
# Out:
# Página 1/2
# 2
# eu sou o main_page_url
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoUF.asp?codigoAcao=8442&codigoFuncao=08&NomeAcao=Transfer%EAncia+de+Renda+Diretamente+%E0s+Fam%EDlias+em+Condi%E7%E3o+de+Pobreza+e+Extrema+Pobreza+%28Lei+n%BA+10%2E836%2C+de+2004%29&Exercicio=2016&Pagina=1
# ACRE
# SOU O state_url
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoMunicipio.asp?Exercicio=2016&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC
# SOU O state_pagination
# Página 1/2
# SOU O state_pages
# 2
# SOU O state_page_url
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoMunicipio.asp?Exercicio=2016&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&Pagina=1
# ESTOU AQUI ACRELANDIA
# SOU O  city_url
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoFavorecido.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoFavorecido.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643
# Página 1/139
# 139
#
# PAGINA1
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoFavorecido.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&Pagina=1
# header
# CNPJ/CPF/NIS/Outros
# Favorecido [Nome Fantasia]
# Total no Ano (R$)
# row 1
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=6296326&cpfcnpjnis=00016167611395
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=6296326&cpfcnpjnis=00016167611395
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "161.67611.39-5",
#     "nome": "ABIGAIL DAGMAR MACHADO",
#     "valor": "1.970,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"209,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"209,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"209,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"209,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"189,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"189,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"189,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"189,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"189,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"189,00\"\n    }\n]"
#     ]
# }
# row 2
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=3466723&cpfcnpjnis=00020225359582
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=3466723&cpfcnpjnis=00020225359582
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "202.25359.58-2",
#     "nome": "ADACIA CARDOSO FIRME",
#     "valor": "2.146,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"229,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"229,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"229,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"229,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"205,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"205,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"205,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"205,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"205,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"205,00\"\n    }\n]"
#     ]
# }
# row 3
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=9774049&cpfcnpjnis=00010679398837
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=9774049&cpfcnpjnis=00010679398837
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "106.79398.83-7",
#     "nome": "ADAIR FERREIRA",
#     "valor": "1.270,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"85,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"85,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"85,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"85,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"155,00\"\n    }\n]"
#     ]
# }
# row 4
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=11796961&cpfcnpjnis=00020796469754
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=11796961&cpfcnpjnis=00020796469754
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "207.96469.75-4",
#     "nome": "ADALCICLEIA BARROS DE ARAUJO",
#     "valor": "942,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"157,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"157,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"157,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"157,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"157,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"157,00\"\n    }\n]"
#     ]
# }
# row 5
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=11257149&cpfcnpjnis=00021221461240
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=11257149&cpfcnpjnis=00021221461240
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "212.21461.24-0",
#     "nome": "ADALCILEIA BARROS DE ARAUJO",
#     "valor": "1.804,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"241,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"241,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"241,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"241,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"140,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"140,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"140,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"140,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"140,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"140,00\"\n    }\n]"
#     ]
# }
# row 6
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=3550714&cpfcnpjnis=00016120063855
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=3550714&cpfcnpjnis=00016120063855
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "161.20063.85-5",
#     "nome": "ADALGIZA NOGUEIRA DOS SANTOS",
#     "valor": "1.996,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"257,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"257,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"257,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"257,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"233,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"147,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"147,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"147,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"147,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"147,00\"\n    }\n]"
#     ]
# }
# row 7
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=9054730&cpfcnpjnis=00023721371727
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=9054730&cpfcnpjnis=00023721371727
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "237.21371.72-7",
#     "nome": "ADAO ANTONIO DA SILVA",
#     "valor": "1.272,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"171,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"171,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"155,00\"\n    }\n]"
#     ]
# }
# row 8
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=14916658&cpfcnpjnis=00021208225415
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=14916658&cpfcnpjnis=00021208225415
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "212.08225.41-5",
#     "nome": "ADEIDE RODRIGUES DAMASCENO",
#     "valor": "2.298,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"342,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"342,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"342,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"342,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"310,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"310,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"310,00\"\n    }\n]"
#     ]
# }
# row 9
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=7880435&cpfcnpjnis=00023684077492
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=7880435&cpfcnpjnis=00023684077492
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "236.84077.49-2",
#     "nome": "ADELCILENE SOARES DA COSTA",
#     "valor": "1.272,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"171,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"171,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"155,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"155,00\"\n    }\n]"
#     ]
# }
# row 10
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=11824565&cpfcnpjnis=00021273189347
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=11824565&cpfcnpjnis=00021273189347
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "212.73189.34-7",
#     "nome": "ADELIA DA COSTA PASSOS",
#     "valor": "2.858,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"305,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"305,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"305,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"305,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"273,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"273,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"273,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"273,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"273,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"273,00\"\n    }\n]"
#     ]
# }
# row 11
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=2777808&cpfcnpjnis=00019033685003
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=2777808&cpfcnpjnis=00019033685003
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "190.33685.00-3",
#     "nome": "ADELIANE BRITO SANTIAGO",
#     "valor": "899,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"124,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"124,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"112,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"112,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"112,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"105,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"105,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"105,00\"\n    }\n]"
#     ]
# }
# row 12
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=4196345&cpfcnpjnis=00016036929952
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=4196345&cpfcnpjnis=00016036929952
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "160.36929.95-2",
#     "nome": "ADELINA XUITES JACOB",
#     "valor": "5.634,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"597,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"597,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"597,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"597,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"541,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"541,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"541,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"541,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"541,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"541,00\"\n    }\n]"
#     ]
# }
# row 13
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=12286525&cpfcnpjnis=00020500011774
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=12286525&cpfcnpjnis=00020500011774
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "205.00011.77-4",
#     "nome": "ADENILDA TAVARES DA SILVA",
#     "valor": "2.513,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"317,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"318,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"318,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"318,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"286,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"286,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"286,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"128,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"128,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"128,00\"\n    }\n]"
#     ]
# }
# row 14
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=15511674&cpfcnpjnis=00020326549867
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=15511674&cpfcnpjnis=00020326549867
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "203.26549.86-7",
#     "nome": "ADENILZA MACHADO PINHEIRO",
#     "valor": "296,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"148,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"148,00\"\n    }\n]"
#     ]
# }
# row 15
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=4007033&cpfcnpjnis=00020666423150
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=4007033&cpfcnpjnis=00020666423150
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "206.66423.15-0",
#     "nome": "ADEUDILENE MARIA PAULA DE OLIVEIRA",
#     "valor": "1.796,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"194,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"194,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"194,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"194,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"170,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"170,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"170,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"170,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"170,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"170,00\"\n    }\n]"
#     ]
# }
#
# PAGINA2
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoFavorecido.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&Pagina=2
# header
# CNPJ/CPF/NIS/Outros
# Favorecido [Nome Fantasia]
# Total no Ano (R$)
# row 1
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=7724701&cpfcnpjnis=00013630107310
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=7724701&cpfcnpjnis=00013630107310
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# {
#     "nis": "136.30107.31-0",
#     "nome": "ADEVANIL DA SILVA",
#     "valor": "2.658,00",
#     "valor_detalhes": [
#         "[\n    {\n        \"Linha\": \"row 1\",\n        \"Mes\": \"Outubro/2016\",\n        \"Valor\": \"285,00\"\n    },\n    {\n        \"Linha\": \"row 2\",\n        \"Mes\": \"Setembro/2016\",\n        \"Valor\": \"285,00\"\n    },\n    {\n        \"Linha\": \"row 3\",\n        \"Mes\": \"Agosto/2016\",\n        \"Valor\": \"285,00\"\n    },\n    {\n        \"Linha\": \"row 4\",\n        \"Mes\": \"Julho/2016\",\n        \"Valor\": \"285,00\"\n    },\n    {\n        \"Linha\": \"row 5\",\n        \"Mes\": \"Junho/2016\",\n        \"Valor\": \"253,00\"\n    },\n    {\n        \"Linha\": \"row 6\",\n        \"Mes\": \"Maio/2016\",\n        \"Valor\": \"253,00\"\n    },\n    {\n        \"Linha\": \"row 7\",\n        \"Mes\": \"Abril/2016\",\n        \"Valor\": \"253,00\"\n    },\n    {\n        \"Linha\": \"row 8\",\n        \"Mes\": \"Mar\\u00e7o/2016\",\n        \"Valor\": \"253,00\"\n    },\n    {\n        \"Linha\": \"row 9\",\n        \"Mes\": \"Fevereiro/2016\",\n        \"Valor\": \"253,00\"\n    },\n    {\n        \"Linha\": \"row 10\",\n        \"Mes\": \"Janeiro/2016\",\n        \"Valor\": \"253,00\"\n    }\n]"
#     ]
# }
# row 2
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=7354746&cpfcnpjnis=00020046062070
# http://www.portaldatransparencia.gov.br/PortalTransparenciaPesquisaAcaoDetalhado.asp?Exercicio=2016&textoPesquisa=&textoPesquisaAcao=&codigoAcao=8442&codigoFuncao=08&siglaEstado=AC&codigoMunicipio=0643&codFavorecido=7354746&cpfcnpjnis=00020046062070
# header
# # of cols7
# Mês Folha
# Mês Competência
# Fonte-Finalidade
# Modalidade de Aplicação
#
#
# Valor (R$)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-94-489a7af661d1> in <module>()
#      24
#      25
# ---> 26 read_main(main_url)
#      27
#      28
#
# <ipython-input-94-489a7af661d1> in read_main(main_url)
#      21         main_page_url = main_url + '&Pagina=' + str(main_page)
#      22         print('eu sou o main_page_url \n'+main_page_url)
# ---> 23         read_main_page(main_page_url)
#      24
#      25
#
# <ipython-input-94-489a7af661d1> in read_main_page(main_url)
#       9             state_url = base_url + td.a.get('href')
#      10             #print(state_url)
# ---> 11             read_state(state_url)
#      12
#      13 def read_main(main_url):
#
# <ipython-input-93-78fef7771497> in read_state(state_url)
#      25         state_page_url = state_url + '&Pagina=' + str(state_page)
#      26         print ("SOU O state_page_url\n"+ state_page_url)
# ---> 27         read_state_page(state_page_url)
#
# <ipython-input-93-78fef7771497> in read_state_page(state_page_url)
#       9             city_url = base_url + td.a.get('href')
#      10             print ('SOU O  city_url\n'+ city_url)
# ---> 11             read_city(city_url)
#      12
#      13
#
# <ipython-input-16-83bbc05e708b> in read_city(city_url)
#      10         city_page_url = city_url + '&Pagina=' + str(city_page)
#      11         print ('\nPAGINA' + str(city_page))
# ---> 12         read_city_page(city_page_url)
#      13
#      14
#
# <ipython-input-20-eeed0f2dd4b9> in read_city_page(city_page_url)
#      33                 person_url = base_url + a.get('href')
#      34                 print (person_url)
# ---> 35                 js = read_person(person_url)
#      36                 linhas ['valor_detalhes'] = []
#      37                 linhas ['valor_detalhes'].append(js)
#
# <ipython-input-15-b8735ce6c0d3> in read_person(person_url)
#      46
#      47     tables = person_soup.findAll("table")
# ---> 48     g = read_table(tables[1])
#      49     h = json.dumps(g, indent=4, sort_keys=True)
#      50     return h
#
# <ipython-input-15-b8735ce6c0d3> in read_table(table)
#      23         a = 'row ' + str(row)
#      24         cols = rows[row].findAll("td", {"class":"firstChild"})
# ---> 25         cols_valor = rows[row].findAll("td", {"class":"colunaValor"})
#      26         for col in cols:
#      27             for col2 in cols_valor:
#
# C:\Users\Léo\Anaconda3\lib\site-packages\bs4\element.py in find_all(self, name, attrs, recursive, text, limit, **kwargs)
#    1297         if not recursive:
#    1298             generator = self.children
# -> 1299         return self._find_all(name, attrs, text, limit, generator, **kwargs)
#    1300     findAll = find_all       # BS3
#    1301     findChildren = find_all  # BS2
#
# C:\Users\Léo\Anaconda3\lib\site-packages\bs4\element.py in _find_all(self, name, attrs, text, limit, generator, **kwargs)
#     526             strainer = name
#     527         else:
# --> 528             strainer = SoupStrainer(name, attrs, text, **kwargs)
#     529
#     530         if text is None and not limit and not attrs and not kwargs:
#
# C:\Users\Léo\Anaconda3\lib\site-packages\bs4\element.py in __init__(self, name, attrs, text, **kwargs)
#    1571     def __init__(self, name=None, attrs={}, text=None, **kwargs):
#    1572         self.name = self._normalize_search_value(name)
# -> 1573         if not isinstance(attrs, dict):
#    1574             # Treat a non-dict value for attrs as a search for the 'class'
#    1575             # attribute.
#
# KeyboardInterrupt:
